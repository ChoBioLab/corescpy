# %%
# %load_ext autoreload
# %autoreload 2

import crispr as cr
from crispr.class_sc import Omics
import pertpy as pt
import pandas as pd
import numpy as np

kwargs_init = dict(assay=None, assay_protein=None,
                   col_sample_id="subset",
                   col_gene_symbols="gene_symbol",  
                   col_cell_type="cell.subtypes",
                   col_condition="clinical.status", 
                   key_control="Healthy", 
                   col_num_umis="nCount_RNA",
                   key_treatment="Inflamed")
# Out:
# ryp2 is not installed. Install with pip install rpy2 to run tools with R support.

# %% [markdown]
# # Object Initialization
#
# Initialize object & add current layer as "log1p" layer because already processed.

# %%
file_path = pt.dt.dialogue_example()
self = Omics(file_path, **kwargs_init)
self.adata.layers[self._layers["log1p"]] = self.adata.X.copy()
# Out:
# <<< INITIALIZING CRISPR CLASS OBJECT >>>
#
# col_gene_symbols='gene_symbol'
# col_cell_type='cell.subtypes'
# col_sample_id='subset'
# col_batch='subset'
# col_condition='clinical.status'
# key_control='Healthy'
# key_treatment='Inflamed'
#
# <<< LOADING OBJECT >>>
#
#
# ================================================================================
# Cell Counts: Raw
# ================================================================================
#
# 5374
#
#
# ================================================================================
# Gene Counts: Raw
# ================================================================================
#
#
#
#  AnnData object with n_obs × n_vars = 5374 × 6329
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset'
#     var: 'name'
#     layers: 'counts'
#
#
#  AnnData object with n_obs × n_vars = 5374 × 6329
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset'
#     var: 'name'
#     layers: 'counts'
#               name
# gene_symbol
# A1CF          A1CF
# AAMDC        AAMDC
# AAMP          AAMP
# AATF          AATF
# ABCC3        ABCC3
#                          nCount_RNA  nFeature_RNA     cellQ  gender location  \
# index
# N7.EpiA.AAACGCACAATCGC  2176.911552           269  0.037467  Female      Epi
# N7.EpiA.AGATATTGATCGGT  4319.159178           660  0.093293  Female      Epi
# N7.EpiA.AGTCTACTTCTCTA  7230.356204          1543  0.242912  Female      Epi
# N7.EpiA.ATATACGAAGTACC  5868.425665          1051  0.155489  Female      Epi
# N7.EpiA.ATCTGTTGTCATTC  3130.076031           432  0.058324  Female      Epi
#
#                        clinical.status cell.subtypes  pathology origin subset
# index
# N7.EpiA.AAACGCACAATCGC    Non-inflamed           TA2       True      A      A
# N7.EpiA.AGATATTGATCGGT    Non-inflamed           TA2       True      A      A
# N7.EpiA.AGTCTACTTCTCTA    Non-inflamed           TA2       True      A      A
# N7.EpiA.ATATACGAAGTACC    Non-inflamed           TA2       True      A      A
# N7.EpiA.ATCTGTTGTCATTC    Non-inflamed           TA2       True      A      A

# %% [markdown]
# # Clustering

# %%
_ = self.cluster()
# Out:
# Un-used Keyword Arguments: {'assay': None, 'col_gene_symbols': 'gene_symbol', 'col_cell_type': 'cell.subtypes', 'col_sample_id': 'subset', 'col_batch': 'subset', 'col_condition': 'clinical.status', 'col_num_umis': 'nCount_RNA', 'key_control': 'Healthy', 'key_treatment': 'Inflamed'}
#
#
# <<< PERFORMING PCA >>>
#
#  {'use_highly_variable': True}
#
#
# <<< COMPUTING NEIGHBORHOOD GRAPH >>>
#
#
#
# <<< EMBEDDING: UMAP >>>
#
#
# <<< CLUSTERING WITH LEIDEN METHOD >>>
#
#
# <<< CREATING UMAP PLOTS >>>

# %% [markdown]
# # Multi-Cellular Program Analysis with Dialogue

# %%
out_2c = self.run_dialogue(n_programs=2, cmap="coolwarm", vcenter=0)
out_3c = self.run_dialogue(n_programs=2, cmap="coolwarm", vcenter=0)
out_confounder = self.run_dialogue(n_programs=2, col_confounder="gender", 
                                   cmap="coolwarm", vcenter=0)
# Out:
# Output()
# 2 MCPs identified for CD8+ IELs and CD8+ IL17+.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/elizabeth/elizabeth/crispr/examples/multicellular_programs.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bspark.chobiolab.org/home/elizabeth/elizabeth/crispr/examples/multicellular_programs.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> out_2c = self.run_dialogue(n_programs=2, cmap="coolwarm", vcenter=0)
#       <a href='vscode-notebook-cell://ssh-remote%2Bspark.chobiolab.org/home/elizabeth/elizabeth/crispr/examples/multicellular_programs.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> out_3c = self.run_dialogue(n_programs=2, cmap="coolwarm", vcenter=0)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bspark.chobiolab.org/home/elizabeth/elizabeth/crispr/examples/multicellular_programs.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> out_confounder = self.run_dialogue(n_programs=2, col_confounder="gender",
#       <a href='vscode-notebook-cell://ssh-remote%2Bspark.chobiolab.org/home/elizabeth/elizabeth/crispr/examples/multicellular_programs.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                                    cmap="coolwarm", vcenter=0)
#
# File ~/crispr/crispr/class_sc.py:517, in Omics.run_dialogue(self, n_programs, col_confounder, col_cell_type, cmap, vcenter, layer, **kws_plot)
#     513 fig = sc.pl.umap(
#     514     pdata, color=mcp_cols + [col, col_cell_type],
#     515     ncols=cols, cmap=cmap, vcenter=vcenter, **kws_plot)
#     516 if col_confounder:  # correct for a confounding variable?
# --> 517     res, p_new = d_l.multilevel_modeling(
#     518         ct_subs=ct_subs, mcp_scores=mcps, ws_dict=w_s,
#     519         confounder=col_confounder)
#     520     self.results[f"dialogue_confounder_{col_confounder}"] = res, p_new
#     521 self.results["dialogue"] = pdata, mcps, w_s, ct_subs
#
# File ~/miniconda3/envs/py-bio/lib/python3.10/site-packages/pertpy/tools/_dialogue.py:793, in Dialogue.multilevel_modeling(self, ct_subs, mcp_scores, ws_dict, confounder, formula)
#     785 ct_data_2 = ct_data_2[ct_data_2.obs[self.sample_id].isin(sample_ids)]
#     787 # TODO: shouldn't need this aligning step for cells. corresponds to @scores / y
#     788 #     scores_1 = cca_scores[cell_type_1].loc[ct_data_1.obs.index]
#     789 #     scores_2 = cca_scores[cell_type_2].loc[ct_data_2.obs.index]
#     790
#     791 # indexes into the average sample expression per gene with the sample id per cell. corresponds to @tme / x
#     792 # TODO: Why is the sample_id type check failing?
# --> 793 tme_1 = self._get_pseudobulks(ct_data_2, groupby=self.sample_id, strategy="mean").loc[
#     794     :, ct_data_1.obs[self.sample_id]
#     795 ]  # unclear why we do this
#     796 tme_1.columns = ct_data_1.obs.index
#     797 tme_2 = self._get_pseudobulks(ct_data_1, groupby=self.sample_id, strategy="mean").loc[
#     798     :, ct_data_2.obs[self.sample_id]
#     799 ]
#
# File ~/miniconda3/envs/py-bio/lib/python3.10/site-packages/pertpy/tools/_dialogue.py:72, in Dialogue._get_pseudobulks(self, adata, groupby, strategy)
#      70         pseudobulk[category] = adata[temp].X.median(axis=0).A1
#      71     elif strategy == "mean":
# ---> 72         pseudobulk[category] = adata[temp].X.mean(axis=0).A1
#      74 pseudobulk = pd.DataFrame(pseudobulk).set_index("Genes")
#      76 return pseudobulk
#
# AttributeError: 'numpy.ndarray' object has no attribute 'A1'
